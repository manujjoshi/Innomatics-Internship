# %% [markdown]
# # Next Word Prediction
#
# This is a simple application of how ngrams can be used in real word. In any messaging application, you tend to see suggestions for the probable next word from the application. A naive version of this can realised with ngrams.

# %%
# Basic Libraries
import bs4 as bs
import urllib.request
import re

import nltk
from nltk import bigrams,trigrams
from collections import defaultdict

# %%
raw_html = urllib.request.urlopen('https://en.wikipedia.org/wiki/Tennis')
raw_html = raw_html.read()

article_html = bs.BeautifulSoup(raw_html, 'lxml')
article_paragraphs = article_html.find_all('p')
article_text = ''

for para in article_paragraphs:
    article_text += para.text

article_text = article_text.lower()
article_text = re.sub(r'[^A-Za-z. ]', '', article_text)
article_text
# Out:
# 'tennis is a racket sport that can be played individually against a single opponent singles or between two teams of two players each doubles. each player uses a tennis racket that is strung with cord to strike a hollow rubber ball covered with felt over or around a net and into the opponents court. the object of the game is to manoeuvre the ball in such a way that the opponent is not able to play a valid return. the player who is unable to return the ball validly will not gain a point while the opposite player will.tennis is an olympic sport and is played at all levels of society and at all ages. the sport can be played by anyone who can hold a racket including wheelchair users. the modern game of tennis originated in birmingham england in the late th century as lawn tennis. it had close connections both to various field lawn games such as croquet and bowls as well as to the older racket sport today called real tennis.the rules of modern tennis have changed little since the s. two exceptions are that until  the server had to keep one foot on the ground at all times and the adoption of the tiebreak in the s. a recent addition to professional tennis has been the adoption of electronic review technology coupled with a pointchallenge system which allows a player to contest the line call of a point a system known as hawkeye.tennis is played by millions of recreational players and is also a popular worldwide spectator sport. the four grand slam tournaments also referred to as the majors are especially popular the australian open played on hard courts the french open played on red clay courts wimbledon played on grass courts and the us open also played on hard courts.historians believe that the games ancient origin lay in th century northern france where a ball was struck with the palm of the hand. louis x of france was a keen player of jeu de paume game of the palm which evolved into real tennis and became notable as the first person to construct indoor tennis courts in the modern style. louis was unhappy with playing tennis outdoors and accordingly had indoor enclosed courts made in paris around the end of the th century. in due course this design spread across royal palaces all over europe. in june  at vincennes valdemarne and following a particularly exhausting game louis drank a large quantity of cooled wine and subsequently died of either pneumonia or pleurisy although there was also suspicion of poisoning. because of the contemporary accounts of his death louis x is historys first tennis player known by name. another of the early enthusiasts of the game was king charles v of france who had a court set up at the louvre palace.it was not until the th century that rackets came into use and the game began to be called tennis from the french term tenez which can be translated as hold receive or take an interjection used as a call from the server to his opponent. it was popular in england and france although the game was only played indoors where the ball could be hit off the wall. henry viii of england was a big fan of this game which is now known as real tennis.an epitaph in st michaels church coventry written circa  read in parthere lyes an old tossd tennis ballwas racketted from spring to fallwith so much heat and so much hasttimes arm for shame grew tyred at last.during the th and early th centuries as real tennis declined new racket sports emerged in england.the invention of the first lawn mower in britain in  is believed to have been a catalyst for the preparation of modernstyle grass courts sporting ovals playing fields pitches greens etc. this in turn led to the codification of modern rules for many sports including lawn tennis most football codes lawn bowls and others.between  and  harry gem a solicitor and his friend augurio perera developed a game that combined elements of racquets and the basque ball game pelota which they played on pereras croquet lawn in birmingham in england. in  along with two local doctors they fou ...

# %% [markdown]
# # Preprocessing
#
# Lets Tokenize the text so that we can construct n-grams

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
tokenized_sent = nltk.word_tokenize(article_text)
tokenized_sent
# Out:
# ['tennis',
#  'is',
#  'a',
#  'racket',
#  'sport',
#  'that',
#  'can',
#  'be',
#  'played',
#  'individually',
#  'against',
#  'a',
#  'single',
#  'opponent',
#  'singles',
#  'or',
#  'between',
#  'two',
#  'teams',
#  'of',
#  'two',
#  'players',
#  'each',
#  'doubles',
#  '.',
#  'each',
#  'player',
#  'uses',
#  'a',
#  'tennis',
#  'racket',
#  'that',
#  'is',
#  'strung',
#  'with',
#  'cord',
#  'to',
#  'strike',
#  'a',
#  'hollow',
#  'rubber',
#  'ball',
#  'covered',
#  'with',
#  'felt',
#  'over',
#  'or',
#  'around',
#  'a',
#  'net',
#  'and',
#  'into',
#  'the',
#  'opponents',
#  'court',
#  '.',
#  'the',
#  'object',
#  'of',
#  'the',
#  'game',
#  'is',
#  'to',
#  'manoeuvre',
#  'the',
#  'ball',
#  'in',
#  'such',
#  'a',
#  'way',
#  'that',
#  'the',
#  'opponent',
#  'is',
#  'not',
#  'able',
#  'to',
#  'play',
#  'a',
#  'valid',
#  'return',
#  '.',
#  'the',
#  'player',
#  'who',
#  'is',
#  'unable',
#  'to',
#  'return',
#  'the',
#  'ball',
#  'validly',
#  'will',
#  'not',
#  'gain',
#  'a',
#  'point',
#  'while',
#  'the',
#  'opposite',
#  'player',
#  'will.tennis',
#  'is',
#  'an',
#  'olympic',
#  'sport',
#  'and',
#  'is',
#  'played',
#  'at',
#  'all',
#  'levels',
#  'of',
#  'society',
#  'and',
#  'at',
#  'all',
#  'ages',
#  '.',
#  'the',
#  'sport',
#  'can',
#  'be',
#  'played',
#  'by',
#  'anyone',
#  'who',
#  'can',
#  'hold',
#  'a',
#  'racket',
#  'including',
#  'wheelchair',
#  'users',
#  '.',
#  'the',
#  'modern',
#  'game',
#  'of',
#  'tennis',
#  'originated',
#  'in',
#  'birmingham',
#  'england',
#  'in',
#  'the',
#  'late',
#  'th',
#  'century',
#  'as',
#  'lawn',
#  'tennis',
#  '.',
#  'it',
#  'had',
#  'close',
#  'connections',
#  'both',
#  'to',
#  'various',
#  'field',
#  'lawn',
#  'games',
#  'such',
#  'as',
#  'croquet',
#  'and',
#  'bowls',
#  'as',
#  'well',
#  'as',
#  'to',
#  'the',
#  'older',
#  'racket',
#  'sport',
#  'today',
#  'called',
#  'real',
#  'tennis.the',
#  'rules',
#  'of',
#  'modern',
#  'tennis',
#  'have',
#  'changed',
#  'little',
#  'since',
#  'the',
#  's.',
#  'two',
#  'exceptions',
#  'are',
#  'that',
#  'until',
#  'the',
#  'server',
#  'had',
#  'to',
#  'keep',
#  'one',
#  'foot',
#  'on',
#  'the',
#  'ground',
#  'at',
#  'all',
#  'times',
#  'and',
#  'the',
#  'adoption',
#  'of',
#  'the',
#  'tiebreak',
#  'in',
#  'the',
#  's.',
#  'a',
#  'recent',
#  'addition',
#  'to',
#  'professional',
#  'tennis',
#  'has',
#  'been',
#  'the',
#  'adoption',
#  'of',
#  'electronic',
#  'review',
#  'technology',
#  'coupled',
#  'with',
#  'a',
#  'pointchallenge',
#  'system',
#  'which',
#  'allows',
#  'a',
#  'player',
#  'to',
#  'contest',
#  'the',
#  'line',
#  'call',
#  'of',
#  'a',
#  'point',
#  'a',
#  'system',
#  'known',
#  'as',
#  'hawkeye.tennis',
#  'is',
#  'played',
#  'by',
#  'millions',
#  'of',
#  'recreational',
#  'players',
#  'and',
#  'is',
#  'also',
#  'a',
#  'popular',
#  'worldwide',
#  'spectator',
#  'sport',
#  '.',
#  'the',
#  'four',
#  'grand',
#  'slam',
#  'tournaments',
#  'also',
#  'referred',
#  'to',
#  'as',
#  'the',
#  'majors',
#  'are',
#  'especially',
#  'popular',
#  'the',
#  'australian',
#  'open',
#  'played',
#  'on',
#  'hard',
#  'courts',
#  'the',
#  'french',
#  'open',
#  'played',
#  'on',
#  'red',
#  'clay',
#  'courts',
#  'wimbledon',
#  'played',
#  'on',
#  'grass',
#  'courts',
#  'and',
#  'the',
#  'us',
#  'open',
#  'also',
#  'played',
#  'on',
#  'hard',
#  'courts.historians',
#  'believe',
#  'that',
#  'the',
#  'games',
#  'ancient',
#  'origin',
#  'lay',
#  'in',
#  'th',
#  'century',
#  'northern',
#  'france',
#  'where',
#  'a',
#  'ball',
#  'was',
#  'struck',
#  'with',
#  'the',
#  'palm',
#  'of',
#  'the',
#  'hand',
#  '.',
#  'louis',
#  'x',
#  'of',
#  'france',
#  'was',
#  'a',
#  'keen',
#  'player',
#  'of',
#  'jeu',
#  'de',
#  'paume',
#  'game',
#  'of',
#  'the',
#  'palm',
#  'which',
#  'evolved',
#  'into',
#  'real',
#  'tennis',
#  'and',
#  'became',
#  'notable',
#  'as',
#  'the',
#  'first',
#  'person',
#  'to',
#  'construct',
#  'indoor',
#  'tennis',
#  'courts',
#  'in',
#  'the',
#  'modern',
#  'style',
#  '.',
#  'louis',
#  'was',
#  'unhappy',
#  'with',
#  'playing',
#  'tennis',
#  'outdoors',
#  'and',
#  'accordingly',
#  'had',
#  'indoor',
#  'enclosed',
#  'courts',
#  'made',
#  'in',
#  'paris',
#  'around',
#  'the',
#  'end',
#  'of',
#  'the',
#  'th',
#  'century',
#  '.',
#  'in',
#  'due',
#  'course',
#  'this',
#  'design',
#  'spread',
#  'across',
#  'royal',
#  'palaces',
#  'all',
#  'over',
#  'europe',
#  '.',
#  'in',
#  'june',
#  'at',
#  'vincennes',
#  'valdemarne',
#  'and',
#  'following',
#  'a',
#  'particularly',
#  'exhausting',
#  'game',
#  'louis',
#  'drank',
#  'a',
#  'large',
#  'quantity',
#  'of',
#  'cooled',
#  'wine',
#  'and',
#  'subsequently',
#  'died',
#  'of',
#  'either',
#  'pneumonia',
#  'or',
#  'pleurisy',
#  'although',
#  'there',
#  'was',
#  'also',
#  'suspicion',
#  'of',
#  'poisoning',
#  '.',
#  'because',
#  'of',
#  'the',
#  'contemporary',
#  'accounts',
#  'of',
#  'his',
#  'death',
#  'louis',
#  'x',
#  'is',
#  'historys',
#  'first',
#  'tennis',
#  'player',
#  'known',
#  'by',
#  'name',
#  '.',
#  'another',
#  'of',
#  'the',
#  'early',
#  'enthusiasts',
#  'of',
#  'the',
#  'game',
#  'was',
#  'king',
#  'charles',
#  'v',
#  'of',
#  'france',
#  'who',
#  'had',
#  'a',
#  'court',
#  'set',
#  'up',
#  'at',
#  'the',
#  'louvre',
#  'palace.it',
#  'was',
#  'not',
#  'until',
#  'the',
#  'th',
#  'century',
#  'that',
#  'rackets',
#  'came',
#  'into',
#  'use',
#  'and',
#  'the',
#  'game',
#  'began',
#  'to',
#  'be',
#  'called',
#  'tennis',
#  'from',
#  'the',
#  'french',
#  'term',
#  'tenez',
#  'which',
#  'can',
#  'be',
#  'translated',
#  'as',
#  'hold',
#  'receive',
#  'or',
#  'take',
#  'an',
#  'interjection',
#  'used',
#  'as',
#  'a',
#  'call',
#  'from',
#  'the',
#  'server',
#  'to',
#  'his',
#  'opponent',
#  '.',
#  'it',
#  'was',
#  'popular',
#  'in',
#  'england',
#  'and',
#  'france',
#  'although',
#  'the',
#  'game',
#  'was',
#  'only',
#  'played',
#  'indoors',
#  'where',
#  'the',
#  'ball',
#  'could',
#  'be',
#  'hit',
#  'off',
#  'the',
#  'wall',
#  '.',
#  'henry',
#  'viii',
#  'of',
#  'england',
#  'was',
#  'a',
#  'big',
#  'fan',
#  'of',
#  'this',
#  'game',
#  'which',
#  'is',
#  'now',
#  'known',
#  'as',
#  'real',
#  'tennis.an',
#  'epitaph',
#  'in',
#  'st',
#  'michaels',
#  'church',
#  'coventry',
#  'written',
#  'circa',
#  'read',
#  'in',
#  'parthere',
#  'lyes',
#  'an',
#  'old',
#  'tossd',
#  'tennis',
#  'ballwas',
#  'racketted',
#  'from',
#  'spring',
#  'to',
#  'fallwith',
#  'so',
#  'much',
#  'heat',
#  'and',
#  'so',
#  'much',
#  'hasttimes',
#  'arm',
#  'for',
#  'shame',
#  'grew',
#  'tyred',
#  'at',
#  'last.during',
#  'the',
#  'th',
#  'and',
#  'early',
#  'th',
#  'centuries',
#  'as',
#  'real',
#  'tennis',
#  'declined',
#  'new',
#  'racket',
#  'sports',
#  'emerged',
#  'in',
#  'england.the',
#  'invention',
#  'of',
#  'the',
#  'first',
#  'lawn',
#  'mower',
#  'in',
#  'britain',
#  'in',
#  'is',
#  'believed',
#  'to',
#  'have',
#  'been',
#  'a',
#  'catalyst',
#  'for',
#  'the',
#  'preparation',
#  'of',
#  'modernstyle',
#  'grass',
#  'courts',
#  'sporting',
#  'ovals',
#  'playing',
#  'fields',
#  'pitches',
#  'greens',
#  'etc',
#  '.',
#  'this',
#  'in',
#  'turn',
#  'led',
#  'to',
#  'the',
#  'codification',
#  'of',
#  'modern',
#  'rules',
#  'for',
#  'many',
#  'sports',
#  'including',
#  'lawn',
#  'tennis',
#  'most',
#  'football',
#  'codes',
#  'lawn',
#  'bowls',
#  'and',
#  'others.between',
#  'and',
#  'harry',
#  'gem',
#  'a',
#  'solicitor',
#  'and',
#  'his',
#  'friend',
#  'augurio',
#  'perera',
#  'developed',
#  'a',
#  'game',
#  'that',
#  'combined',
#  'elements',
#  'of',
#  'racquets',
#  'and',
#  'the',
#  'basque',
#  'ball',
#  'game',
#  'pelota',
#  'which',
#  'they',
#  'played',
#  'on',
#  'pereras',
#  'croquet',
#  'lawn',
#  'in',
#  'birmingham',
#  'in',
#  'england',
#  '.',
#  'in',
#  'along',
#  'with',
#  'two',
#  'local',
#  'doctors',
#  'they',
#  'founded',
#  'the',
#  'worlds',
#  'first',
#  'tennis',
#  'club',
#  'on',
#  'avenue',
#  'road',
#  'leamington',
#  'spa',
#  '.',
#  'this',
#  'is',
#  'where',
#  'lawn',
#  'tennis',
#  'was',
#  'used',
#  'as',
#  'a',
#  'name',
#  'of',
#  'activity',
#  'by',
#  'a',
#  'club',
#  'for',
#  'the',
#  'first',
#  'time.in',
#  'tennis',
#  'a',
#  'cultural',
#  'history',
#  'heiner',
#  'gillmeister',
#  'reveals',
#  'that',
#  'on',
#  'december',
#  'british',
#  'army',
#  'officer',
#  'walter',
#  'clopton',
#  'wingfield',
#  'wrote',
#  'to',
#  'harry',
#  'gem',
#  'commenting',
#  'that',
#  'he',
#  'wingfield',
#  'had',
#  'been',
#  'experimenting',
#  'with',
#  'his',
#  'version',
#  'of',
#  'lawn',
#  'tennis',
#  'for',
#  'a',
#  'year',
#  'and',
#  'a',
#  'half',
#  '.',
#  'in',
#  'december',
#  'wingfield',
#  'designed',
#  'and',
#  'patented',
#  'a',
#  'game',
#  'which',
#  'he',
#  'called',
#  'sphairistik',
#  'greek',
#  'meaning',
#  'ballplaying',
#  'and',
#  'was',
#  'soon',
#  'known',
#  'simply',
#  'as',
#  'sticky',
#  'for',
#  'the',
#  'amusement',
#  'of',
#  'guests',
#  'at',
#  'a',
#  'garden',
#  'party',
#  'on',
#  'his',
#  'friends',
#  'estate',
#  'of',
#  'nantclwyd',
#  'hall',
#  'in',
#  'llanelidan',
#  'wales',
#  '.',
#  'according',
#  'to',
#  'r.',
#  'd.',
#  'c.',
#  'evans',
#  'turfgrass',
#  'agronomist',
#  'sports',
#  'historians',
#  'all',
#  'agree',
#  'that',
#  'wingfield',
#  'deserves',
#  'much',
#  'of',
#  'the',
#  'credit',
#  'for',
#  'the',
#  'development',
#  'of',
#  'modern',
#  'tennis',
#  '.',
#  'according',
#  'to',
#  'honor',
#  'godfrey',
#  'museum',
#  'curator',
#  'at',
#  'wimbledon',
#  'wingfield',
#  'popularized',
#  'this',
#  'game',
#  'enormously',
#  '.',
#  'he',
#  'produced',
#  'a',
#  'boxed',
#  'set',
#  'which',
#  'included',
#  'a',
#  'net',
#  'poles',
#  'rackets',
#  'balls',
#  'for',
#  'playing',
#  'the',
#  'game',
#  'and',
#  'most',
#  'importantly',
#  'you',
#  'had',
#  'his',
#  'rules',
#  '.',
#  'he',
#  'was',
#  'absolutely',
#  'terrific',
#  'at',
#  'marketing',
#  'and',
#  'he',
#  'sent',
#  'his',
#  'game',
#  'all',
#  'over',
#  'the',
#  'world',
#  '.',
#  'he',
#  'had',
#  'very',
#  'good',
#  'connections',
#  'with',
#  'the',
#  'clergy',
#  'the',
#  'law',
#  'profession',
#  'and',
#  'the',
#  'aristocracy',
#  'and',
#  'he',
#  'sent',
#  'thousands',
#  'of',
#  'sets',
#  'out',
#  'in',
#  'the',
#  'first',
#  'year',
#  'or',
#  'so',
#  'in',
#  '.',
#  'the',
#  'worlds',
#  'oldest',
#  'annual',
#  'tennis',
#  'tournament',
#  'took',
#  'place',
#  'at',
#  'leamington',
#  'lawn',
#  'tennis',
#  'club',
#  'in',
#  'birmingham',
#  'in',
#  '.',
#  'this',
#  'was',
#  'three',
#  'years',
#  'before',
#  'the',
#  'all',
#  'england',
#  'lawn',
#  'tennis',
#  'and',
#  'croquet',
#  'club',
#  'would',
#  'hold',
#  'its',
#  'first',
#  'championships',
#  'at',
#  'wimbledon',
#  'in',
#  '.',
#  'the',
#  'first',
#  'championships',
#  'culminated',
#  'in',
#  'a',
#  'significant',
#  'debate',
#  'on',
#  'how',
#  'to',
#  'standardise',
#  'the',
#  ...]

# %% [markdown]
# ---
# # Generating N-Gram Model

# %% [markdown]
# ---
# # 2-Gram

# %%
# Create a placeholder for model
model_2_gram = defaultdict(lambda: defaultdict(lambda: 0))

# Count frequency of co-occurance  
for w1, w2 in bigrams(tokenized_sent):
    model_2_gram[(w1)][w2] += 1

# Let's transform the counts to probabilities
for w1 in model_2_gram:
    total_count = float(sum(model_2_gram[w1].values()))
    for w2 in model_2_gram[w1]:
        model_2_gram[w1][w2] /= total_count

# %%
model_2_gram
# Out:
# defaultdict(<function __main__.<lambda>>,
#             {'tennis': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'.': 0.05970149253731343,
#                           'a': 0.014925373134328358,
#                           'after': 0.007462686567164179,
#                           'almost': 0.007462686567164179,
#                           'and': 0.022388059701492536,
#                           'as': 0.007462686567164179,
#                           'association': 0.05970149253731343,
#                           'australia': 0.007462686567164179,
#                           'balls': 0.022388059701492536,
#                           'balls.tennis': 0.007462686567164179,
#                           'ballwas': 0.007462686567164179,
#                           'by': 0.007462686567164179,
#                           'can': 0.007462686567164179,
#                           'championships': 0.007462686567164179,
#                           'channel': 0.007462686567164179,
#                           'circuit': 0.007462686567164179,
#                           'club': 0.014925373134328358,
#                           'competitions': 0.007462686567164179,
#                           'court': 0.014925373134328358,
#                           'courts': 0.007462686567164179,
#                           'declined': 0.007462686567164179,
#                           'during': 0.007462686567164179,
#                           'especially': 0.007462686567164179,
#                           'events': 0.007462686567164179,
#                           'fans': 0.014925373134328358,
#                           'federation': 0.04477611940298507,
#                           'followed': 0.007462686567164179,
#                           'for': 0.014925373134328358,
#                           'format': 0.007462686567164179,
#                           'former': 0.007462686567164179,
#                           'french': 0.007462686567164179,
#                           'from': 0.007462686567164179,
#                           'game': 0.007462686567164179,
#                           'hall': 0.007462686567164179,
#                           'has': 0.007462686567164179,
#                           'these': 0.016025641025641024,
#                           'they': 0.003205128205128205,
#                           'thirty': 0.003205128205128205,
#                           'this': 0.01282051282051282,
#                           'three': 0.003205128205128205,
#                           'tightly': 0.003205128205128205,
#                           'titles': 0.003205128205128205,
#                           'torso': 0.003205128205128205,
#                           'total': 0.003205128205128205,
#                           'tournament': 0.003205128205128205,
#                           'tournaments': 0.01282051282051282,
#                           'twelve': 0.003205128205128205,
#                           'two': 0.00641025641025641,
#                           'us': 0.003205128205128205,
#                           'view': 0.003205128205128205,
#                           'womens': 0.009615384615384616,
#                           'wood': 0.003205128205128205,
#                           'years': 0.003205128205128205}),
#              'players': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'.': 0.05,
#                           'alternate': 0.01,
#                           'an': 0.01,
#                           'and': 0.03,
#                           'are': 0.02,
#                           'as': 0.01,
#                           'at': 0.01,
#                           'atp': 0.01,
#                           'attempt': 0.01,
#                           'between': 0.01,
#                           'but': 0.01,
#                           'change': 0.02,
#                           'compete': 0.01,
#                           'control': 0.01,
#                           'could': 0.01,
#                           'court': 0.01,
#                           'each': 0.01,
#                           'earn': 0.01,
#                           'enjoy': 0.01,
#                           'feet': 0.01,
#                           'foot': 0.01,
#                           'for': 0.02,
#                           'from': 0.01,
#                           'grunting': 0.01,
#                           'have': 0.02,
#                           'he': 0.01,
#                           'however': 0.01,
#                           'in': 0.03,
#                           'including': 0.01,
#                           'known': 0.01,
#                           'may': 0.01,
#                           'most': 0.01,
#                           'notably': 0.01,
#                           'of': 0.05,
#                           'often': 0.01,
#                           'on': 0.02,
#                           'or': 0.02,
#                           'other': 0.01,
#                           'outside': 0.01,
#                           'play': 0.01,
#                           'playing': 0.01,
#                           'position': 0.01,
#                           'ranked': 0.01,
#                           'receive': 0.01,
#                           'rotate': 0.01,
#                           'score': 0.02,
#                           'scores': 0.01,
#                           'serve': 0.01,
#                           'side': 0.01,
#                           'strive': 0.01,
#                           'such': 0.03,
#                           'techniques': 0.01,
#                           'that': 0.03,
#                           'the': 0.01,
#                           'to': 0.06,
#                           'under': 0.01,
#                           'use': 0.03,
#                           'used': 0.01,
#                           'voted': 0.01,
#                           'was': 0.01,
#                           'were': 0.01,
#                           'who': 0.02,
#                           'will': 0.02,
#                           'with': 0.04,
#                           'would': 0.01}),
#              'each': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'baseline': 0.04,
#                           'became': 0.04,
#                           'club': 0.04,
#                           'doubles': 0.04,
#                           'event': 0.04,
#                           'game': 0.12,
#                           'gender.most': 0.04,
#                           'hosted': 0.04,
#                           'now': 0.04,
#                           'player': 0.2,
#                           'point': 0.08,
#                           'side': 0.12,
#                           'side.the': 0.04,
#                           'taking': 0.04,
#                           'tournament': 0.04,
#                           'year.in': 0.04}),
#              'doubles': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'.': 0.05357142857142857,
#                           'alley': 0.017857142857142856,
#                           'and': 0.05357142857142857,
#                           'another': 0.017857142857142856,
#                           'as': 0.03571428571428571,
#                           'at': 0.017857142857142856,
#                           'by': 0.017857142857142856,
#                           'champions': 0.017857142857142856,
#                           'contests': 0.017857142857142856,
#                           'counterparts': 0.017857142857142856,
#                           'court': 0.017857142857142856,
#                           'during': 0.017857142857142856,
#                           'events': 0.017857142857142856,
#                           'finishing': 0.017857142857142856,
#                           'fitted': 0.017857142857142856,
#                           'has': 0.017857142857142856,
#                           'he': 0.017857142857142856,
#                           'into': 0.017857142857142856,
# ...
#                          {'shape': 1.0}),
#              'shape': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'of': 1.0}),
#              'rectangle.tennis': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'is': 1.0}),
#              'unusual': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'in': 1.0}),
#              'variety': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'of': 1.0}),
#              'surfaces': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'.': 0.25,
#                           'accommodating': 0.25,
#                           'grass': 0.25,
#                           'hard': 0.25}),
#              'concrete': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'or': 1.0}),
#              'asphalt': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'topped': 1.0}),
#              'topped': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'with': 1.0}),
#              'acrylic': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'are': 1.0}),
#              'common': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'.': 0.16666666666666666,
#                           'cause': 0.16666666666666666,
#                           'in': 0.16666666666666666,
#                           'injuries': 0.16666666666666666,
#                           'stance': 0.16666666666666666,
#                           'tournament': 0.16666666666666666}),
#              'occasionally': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'carpet': 0.5, 'leading': 0.5}),
#              'carpet': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'is': 1.0}),
#              'hardwood': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'flooring': 1.0}),
#              'flooring': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'having': 1.0}),
#              'having': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'a': 0.25,
#                           'been': 0.25,
#                           'doubles': 0.25,
#                           'to': 0.25}),
#              'historically': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'used': 1.0}),
#              'artificial': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'turf': 1.0}),
#              'turf': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'courts': 1.0}),
#              'found.the': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'lines': 1.0}),
#              'lines': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'are': 0.2, 'or': 0.2, 'that': 0.4, 'to': 0.2}),
#              'delineate': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'the': 1.0}),
#              'baseline': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'between': 0.16666666666666666,
#                           'farthest': 0.16666666666666666,
#                           'is': 0.16666666666666666,
#                           'or': 0.16666666666666666,
#                           'the': 0.16666666666666666,
#                           'which': 0.16666666666666666}),
#              'farthest': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'back': 1.0}),
#              'back': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'.': 0.25, 'and': 0.25, 'spin': 0.25, 'up': 0.25}),
#              'service': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'.': 0.047619047619047616,
#                           'after': 0.047619047619047616,
#                           'alternates': 0.047619047619047616,
#                           'alternating': 0.047619047619047616,
#                           'box': 0.19047619047619047,
#                           'boxes': 0.047619047619047616,
#                           'in': 0.047619047619047616,
#                           'is': 0.047619047619047616,
#                           'line': 0.2857142857142857,
#                           'returner': 0.047619047619047616,
#                           'starts': 0.047619047619047616,
#                           'to': 0.047619047619047616,
#                           'which': 0.047619047619047616}),
#              'middle': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'of': 1.0}),
#              'short': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'mark': 1.0}),
#              'mark': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'.': 0.14285714285714285,
#                           'and': 0.14285714285714285,
#                           'before': 0.14285714285714285,
#                           'in': 0.14285714285714285,
#                           'left': 0.14285714285714285,
#                           'or': 0.14285714285714285,
#                           'woodforde': 0.14285714285714285}),
#              'hash': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'mark': 1.0}),
#              'outermost': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'lines': 1.0}),
#              'sidelines': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'and': 0.3333333333333333,
#                           'are': 0.3333333333333333,
#                           'they': 0.3333333333333333}),
#              'boundaries': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'for': 0.5, 'in': 0.5}),
#              'inside': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'of': 0.5, 'the': 0.5}),
#              'area': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'between': 0.5, 'inside': 0.25, 'of': 0.25}),
#              'sideline': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'.': 0.3333333333333333,
#                           'and': 0.3333333333333333,
#                           'is': 0.3333333333333333}),
#              'nearest': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'singles': 1.0}),
#              'alley': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'playable': 1.0}),
#              'playable': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'in': 1.0}),
#              'runs': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'across': 1.0}),
#              'serve': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'.': 0.09375,
#                           'although': 0.03125,
#                           'and': 0.125,
#                           'any': 0.03125,
#                           'as': 0.03125,
#                           'by': 0.03125,
#                           'forehand': 0.03125,
#                           'in': 0.03125,
#                           'including': 0.03125,
#                           'is': 0.125,
#                           'may': 0.03125,
#                           'must': 0.03125,
#                           'of': 0.03125,
#                           'one': 0.03125,
#                           'or': 0.03125,
#                           'set': 0.03125,
#                           'simply': 0.03125,
#                           'slice': 0.03125,
#                           'that': 0.0625,
#                           'then': 0.03125,
#                           'to': 0.03125,
#                           'topspin': 0.03125,
#                           'were': 0.03125}),
#              'delivered': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'into': 1.0}),
#              'receiving': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'player': 0.5, 'side': 0.5}),
#              'despite': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'its': 1.0}),
#              'legally': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'protected': 0.5, 'stands': 0.5}),
#              'stands': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'when': 1.0}),
#              'making': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'a': 0.2,
#                           'it': 0.2,
#                           'more': 0.2,
#                           'powerful': 0.2,
#                           'the': 0.2}),
#              'serve.the': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'line': 1.0}),
#              'boxes': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'depending': 0.5, 'this': 0.5}),
#              'creates': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'are': 1.0}),
#              'depending': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'on': 0.75, 'upon': 0.25}),
#              'position': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'after': 0.25,
#                           'on': 0.25,
#                           'or': 0.25,
#                           'they': 0.25}),
#              'serving': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'.': 0.4444444444444444,
#                           'has': 0.1111111111111111,
#                           'is': 0.1111111111111111,
#                           'player': 0.1111111111111111,
#                           'players': 0.1111111111111111,
#                           'remains': 0.1111111111111111}),
#              'if': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'a': 0.037037037037037035,
#                           'at': 0.07407407407407407,
#                           'he': 0.037037037037037035,
#                           'however': 0.037037037037037035,
#                           'in': 0.037037037037037035,
#                           'none': 0.037037037037037035,
#                           'one': 0.037037037037037035,
#                           'play': 0.037037037037037035,
#                           'spinning': 0.037037037037037035,
#                           'the': 0.5925925925925926,
#                           'they': 0.037037037037037035}),
#              'none': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'of': 1.0}),
#              'upon': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'its': 0.25,
#                           'landing': 0.25,
#                           'right': 0.25,
#                           'the': 0.25}),
#              'mm': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'in': 0.5, 'wide': 0.5}),
#              'exception': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'is': 0.5, 'of': 0.5}),
#              'practice': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'it': 1.0}),
#              'often': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'apply': 0.1,
#                           'leading': 0.1,
#                           'means': 0.1,
#                           'nominated.in': 0.1,
#                           'organized': 0.1,
#                           'signal': 0.1,
#                           'skip': 0.1,
#                           'taught': 0.1,
#                           'the': 0.1,
#                           'try': 0.1}),
#              'others.the': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'players': 1.0}),
#              'start': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'a': 0.2, 'anywhere': 0.2, 'of': 0.4, 'on': 0.2}),
#              'sides': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'of': 1.0}),
#              'designated': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'the': 1.0}),
#              'opposing': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'player': 1.0}),
#              'receiver': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'.': 0.0625,
#                           'and': 0.0625,
#                           'before': 0.0625,
#                           'does': 0.0625,
#                           'fails': 0.0625,
#                           'has': 0.0625,
#                           'in': 0.0625,
#                           'is': 0.125,
#                           'isnt': 0.0625,
#                           'may': 0.0625,
#                           'must': 0.0625,
#                           'not': 0.0625,
#                           'the': 0.0625,
#                           'who': 0.0625,
#                           'wins': 0.0625}),
#              'choice': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'of': 0.5, 'to': 0.5}),
#              'coin': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'toss': 1.0}),
#              'toss': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'before': 1.0}),
#              'warmup': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'.': 0.5, 'starts': 0.5}),
#              'starts': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'.': 0.3333333333333333,
#                           'a': 0.3333333333333333,
#                           'behind': 0.3333333333333333}),
#              'alternates': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'game': 1.0}),
#              'behind': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'and': 0.5, 'the': 0.5}),
#              'anywhere': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'on': 1.0}),
#              'ready': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'the': 1.0}),
#              'pace': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'of': 0.5, 'spin': 0.5}),
#              'server.for': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'a': 1.0}),
#              'legal': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'return': 0.5,
#                           'service': 0.16666666666666666,
#                           'service.a': 0.16666666666666666,
#                           'the': 0.16666666666666666}),
#              'travel': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'over': 1.0}),
#              'without': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'time': 0.3333333333333333,
#                           'touching': 0.6666666666666666}),
#              'touching': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {'it': 0.5, 'the': 0.5}),
#              ...})

# %% [markdown]
# ---
# # 3-Gram

# %%
# Create a placeholder for model
model_3_gram = defaultdict(lambda: defaultdict(lambda: 0))

# Count frequency of co-occurance  
for w1, w2, w3 in trigrams(tokenized_sent, pad_right=True, pad_left=True):
    model_3_gram[(w1, w2)][w3] += 1

# Let's transform the counts to probabilities
for w1_w2 in model_3_gram:
    total_count = float(sum(model_3_gram[w1_w2].values()))
    for w3 in model_3_gram[w1_w2]:
        model_3_gram[w1_w2][w3] /= total_count

# %%
model_3_gram
# Out:
# defaultdict(<function __main__.<lambda>>,
#             {(None,
#               None): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'tennis': 1.0}),
#              (None,
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'is': 1.0}),
#              ('tennis',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 0.5,
#                           'played': 0.25,
#                           'the': 0.25}),
#              ('is',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'break': 0.06666666666666667,
#                           'diagonal': 0.06666666666666667,
#                           'group': 0.06666666666666667,
#                           'let': 0.06666666666666667,
#                           'player': 0.06666666666666667,
#                           'racket': 0.06666666666666667,
#                           'relevant': 0.06666666666666667,
#                           'serve': 0.06666666666666667,
#                           'shot': 0.13333333333333333,
#                           'stroke': 0.13333333333333333,
#                           'system': 0.06666666666666667,
#                           'very': 0.06666666666666667,
#                           'way': 0.06666666666666667}),
#              ('a',
#               'racket'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 0.3333333333333333,
#                           'including': 0.3333333333333333,
#                           'sport': 0.3333333333333333}),
#              ('racket',
#               'sport'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'that': 0.5,
#                           'today': 0.5}),
#              ('sport',
#               'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'can': 1.0}),
#              ('that',
#               'can'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'be': 1.0}),
#              ('can',
#               'be'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'coiled': 0.09090909090909091,
#                           'either': 0.09090909090909091,
#                           'executed': 0.09090909090909091,
#                           'played': 0.2727272727272727,
#                           'stiff': 0.09090909090909091,
#                           'translated': 0.09090909090909091,
#                           'up': 0.09090909090909091,
#                           'used': 0.09090909090909091,
#                           'won': 0.09090909090909091}),
#              ('be',
#               'played'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'by': 0.6666666666666666,
#                           'individually': 0.3333333333333333}),
#              ('played',
#               'individually'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'against': 1.0}),
#              ('individually',
#               'against'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 1.0}),
#              ('against',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'doubles': 0.5,
#                           'single': 0.5}),
#              ('a',
#               'single'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'opponent': 1.0}),
#              ('single',
#               'opponent'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'singles': 1.0}),
#              ('opponent',
#               'singles'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'or': 1.0}),
#              ('singles',
#               'or'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'between': 1.0}),
#              ('or',
#               'between'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'two': 1.0}),
#              ('between',
#               'two'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'teams': 1.0}),
#              ('two',
#               'teams'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1.0}),
#              ('teams',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'two': 1.0}),
#              ('of',
#               'two'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'male': 0.5,
#                           'players': 0.5}),
#              ('two',
#               'players'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'each': 0.25,
#                           'or': 0.25,
#                           'play': 0.25,
#                           'serve': 0.25}),
#              ('players',
#               'each'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'doubles': 1.0}),
#              ('each',
#               'doubles'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 1.0}),
#              ('doubles',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'each': 0.3333333333333333,
#                           'it': 0.3333333333333333,
#                           'this': 0.3333333333333333}),
#              ('.',
#               'each'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'event': 0.5,
#                           'player': 0.5}),
#              ('each',
#               'player'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'at': 0.2,
#                           'making': 0.2,
#                           'plays': 0.2,
#                           'taking': 0.2,
#                           'uses': 0.2}),
#              ('player',
#               'uses'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 1.0}),
#              ('uses',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'tennis': 1.0}),
#              ('a',
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'court': 0.2,
#                           'game': 0.2,
#                           'racket': 0.6}),
#              ('tennis',
#               'racket'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'include': 0.3333333333333333,
#                           'is': 0.3333333333333333,
#                           'that': 0.3333333333333333}),
#              ('racket',
#               'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'is': 1.0}),
#              ('that',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'adjusted': 0.3333333333333333,
#                           'not': 0.3333333333333333,
#                           'strung': 0.3333333333333333}),
#              ('is',
#               'strung'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'with': 1.0}),
#              ('strung',
#               'with'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'cord': 0.5,
#                           'two': 0.5}),
#              ('with',
#               'cord'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 1.0}),
#              ('cord',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'strike': 1.0}),
#              ('to',
#               'strike'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 1.0}),
#              ('strike',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'hollow': 1.0}),
#              ('a',
#               'hollow'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'rubber': 1.0}),
#              ('hollow',
#               'rubber'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'ball': 1.0}),
#              ('rubber',
#               'ball'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'covered': 1.0}),
#              ('ball',
#               'covered'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'with': 1.0}),
#              ('covered',
#               'with'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'felt': 1.0}),
#              ('with',
#               'felt'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'over': 1.0}),
#              ('felt',
#               'over'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'or': 1.0}),
#              ('over',
#               'or'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'around': 0.5,
#                           'round': 0.5}),
#              ('or',
#               'around'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 1.0}),
#              ('around',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'net': 1.0}),
#              ('a',
#               'net'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 0.2,
#                           'is': 0.2,
#                           'judge': 0.4,
#                           'poles': 0.2}),
#              ('net',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'ahead': 0.25,
#                           'into': 0.25,
#                           'is': 0.25,
#                           'played': 0.25}),
#              ('and',
#               'into'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('into',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'air': 0.08333333333333333,
#                           'area': 0.08333333333333333,
#                           'correct': 0.08333333333333333,
#                           'diagonally': 0.16666666666666666,
#                           'opponents': 0.25,
#                           'opposite': 0.08333333333333333,
#                           'other': 0.16666666666666666,
#                           'shot': 0.08333333333333333}),
#              ('the',
#               'opponents'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'court': 0.8,
#                           'head': 0.2}),
#              ('opponents',
#               'court'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 0.5,
#                           'much': 0.25,
#                           'to': 0.25}),
#              ('court',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a':
#                           'greatest': 0.01020408163265306,
#                           'hand': 0.01020408163265306,
#                           'itf.in': 0.01020408163265306,
#                           'match': 0.030612244897959183,
#                           'mens': 0.01020408163265306,
#                           'modern': 0.01020408163265306,
#                           'most': 0.02040816326530612,
#                           'net': 0.04081632653061224,
#                           'next': 0.01020408163265306,
#                           'nine': 0.01020408163265306,
#                           'number': 0.01020408163265306,
#                           'olympic': 0.01020408163265306,
#                           'open': 0.030612244897959183,
#                           'opponents': 0.01020408163265306,
#                           'other': 0.01020408163265306,
#                           'palm': 0.01020408163265306,
#                           'players': 0.01020408163265306,
#                           'previous': 0.01020408163265306,
#                           'racket': 0.01020408163265306,
#                           's': 0.01020408163265306,
#                           'same': 0.01020408163265306,
#                           'second': 0.01020408163265306,
#                           'secondhighest': 0.01020408163265306,
#                           'series': 0.01020408163265306,
#                           'server': 0.02040816326530612,
#                           'server.for': 0.01020408163265306,
#                           'service': 0.02040816326530612,
#                           'set': 0.02040816326530612,
#                           'shot': 0.04081632653061224,
#                           'tennis': 0.01020408163265306,
#                           'th': 0.08163265306122448,
#                           'three': 0.01020408163265306,
#                           'tiebreak': 0.02040816326530612,
#                           'top': 0.01020408163265306,
#                           'twentieth': 0.01020408163265306,
#                           'very': 0.01020408163265306,
#                           'worlds': 0.01020408163265306}),
#              ('the',
#               'game'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 0.2,
#                           'and': 0.1,
#                           'began': 0.05,
#                           'has': 0.05,
#                           'in': 0.05,
#                           'is': 0.2,
#                           'needs': 0.05,
#                           'of': 0.05,
#                           'so': 0.05,
#                           'tying': 0.05,
#                           'was': 0.1,
#                           'with': 0.05}),
#              ('game',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'advantage': 0.14285714285714285,
#                           'also': 0.14285714285714285,
#                           'awarded': 0.14285714285714285,
#                           'described': 0.14285714285714285,
#                           'played': 0.14285714285714285,
#                           'to': 0.14285714285714285,
#                           'won': 0.14285714285714285}),
#              ('is',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'allow': 0.3333333333333333,
#                           'assign': 0.3333333333333333,
#                           'manoeuvre': 0.3333333333333333}),
#              ('to',
#               'manoeuvre'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('manoeuvre',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'ball': 1.0}),
#              ('the',
#               'ball'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 0.02857142857142857,
#                           'across': 0.02857142857142857,
#                           'and': 0.14285714285714285,
#                           'bounces': 0.02857142857142857,
#                           'change': 0.02857142857142857,
#                           'could': 0.02857142857142857,
#                           'has': 0.05714285714285714,
#                           'high': 0.02857142857142857,
#                           'hits': 0.05714285714285714,
#                           'in': 0.05714285714285714,
#                           'into': 0.11428571428571428,
#                           'is': 0.05714285714285714,
#                           'just': 0.02857142857142857,
#                           'must': 0.05714285714285714,
#                           'on': 0.02857142857142857,
#                           'opposite': 0.02857142857142857,
#                           'or': 0.02857142857142857,
#                           'so': 0.02857142857142857,
#                           'than': 0.02857142857142857,
#                           'to': 0.05714285714285714,
#                           'twice': 0.02857142857142857,
#                           'validly': 0.02857142857142857}),
#              ('ball',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'boston': 0.5,
#                           'such': 0.5}),
#              ('in',
#               'such'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 0.5,
#                           'cases': 0.5}),
#              ('such',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'way': 1.0}),
#              ('a',
#               'way'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 0.5,
#                           'that': 0.5}),
#              ('way',
#               'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('that',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'company': 0.2,
#                           'games': 0.2,
#                           'loser': 0.2,
#                           'opponent': 0.4}),
#              ('the',
#               'opponent'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 0.3333333333333333,
#                           'as': 0.1111111111111111,
#                           'five': 0.1111111111111111,
#                           'in': 0.1111111111111111,
#                           'is': 0.3333333333333333}),
#              ('opponent',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'called': 0.25,
#                           'deep': 0.25,
#                           'not': 0.25,
#                           'unable': 0.25}),
#              ('is',
#               'not'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'able': 0.16666666666666666,
#                           'called': 0.16666666666666666,
#                           'hit': 0.16666666666666666,
#                           'sanctioned': 0.16666666666666666,
#                           'touched': 0.16666666666666666,
#                           'where': 0.16666666666666666}),
#              ('not',
#               'able'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 1.0}),
#              ('able',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'make': 0.3333333333333333,
#                           'play': 0.3333333333333333,
#                           'return': 0.3333333333333333}),
#              ('to',
#               'play'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 0.14285714285714285,
#                           'a': 0.14285714285714285,
#                           'against': 0.14285714285714285,
#                           'backhand': 0.14285714285714285,
#                           'doubles': 0.14285714285714285,
#                           'in': 0.14285714285714285,
#                           'the': 0.14285714285714285}),
#              ('play',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'player': 0.5,
#                           'valid': 0.5}),
#              ('a',
#               'valid'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'return': 1.0}),
#              ('valid',
#               'return'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 1.0}),
#              ('return',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('the',
#               'player'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'approaches': 0.07142857142857142,
#                           'can': 0.07142857142857142,
#                           'crouching': 0.07142857142857142,
#                           'has': 0.14285714285714285,
#                           'in': 0.07142857142857142,
#                           'long': 0.07142857142857142,
#                           'more': 0.07142857142857142,
#                           'to': 0.07142857142857142,
#                           'who': 0.2857142857142857,
#                           'wins': 0.07142857142857142}),
#              ('player',
#               'who'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'is': 1.0}),
#              ('who',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'consistently': 0.14285714285714285,
#                           'in': 0.14285714285714285,
#                           'serving': 0.14285714285714285,
#                           'still': 0.14285714285714285,
#                           'the': 0.14285714285714285,
#                           'unable': 0.14285714285714285,
#                           'usually': 0.14285714285714285}),
#              ('is',
#               'unable'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 1.0}),
#              ('unable',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'return': 0.5,
#                           'run': 0.5}),
#              ('to',
#               'return'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 0.5,
#                           'the': 0.5}),
#              ('return',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'ball': 1.0}),
#              ('ball',
#               'validly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'will': 1.0}),
#              ('validly',
#               'will'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'not': 1.0}),
#              ('will',
#               'not'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'gain': 1.0}),
#              ('not',
#               'gain'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 1.0}),
#              ('gain',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'point': 1.0}),
#              ('a',
#               'point'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 0.2,
#                           'a': 0.2,
#                           'and': 0.2,
#                           'event': 0.2,
#                           'while': 0.2}),
#              ('point',
#               'while'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('while',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'atp': 0.25,
#                           'doubles': 0.25,
#                           'opposite': 0.25,
#                           'women': 0.25}),
#              ('the',
#               'opposite'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'player': 0.5,
#                           'side': 0.5}),
#              ('opposite',
#               'player'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'will.tennis': 1.0}),
#              ('player',
#               'will.tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'is': 1.0}),
#              ('will.tennis',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'an': 1.0}),
#              ('is',
#               'an'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'offensive': 0.3333333333333333,
#                           'officiating': 0.3333333333333333,
#                           'olympic': 0.3333333333333333}),
#              ('an',
#               'olympic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'medal': 0.5,
#                           'sport': 0.5}),
#              ('olympic',
#               'sport'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1.0}),
#              ('sport',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'is': 1.0}),
#              ('and',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 0.1,
#                           'also': 0.1,
#                           'easier': 0.1,
#                           'generally': 0.1,
#                           'now': 0.1,
#                           'played': 0.1,
#                           'regarded': 0.2,
#                           'used': 0.1,
#                           'usually': 0.1}),
#              ('is',
#               'played'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 0.25,
#                           'at': 0.125,
#                           'by': 0.125,
#                           'on': 0.25,
#                           'the': 0.125,
#                           'with': 0.125}),
#              ('played',
#               'at'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'all': 1.0}),
#              ('at',
#               'all'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'ages': 0.16666666666666666,
#                           'four': 0.16666666666666666,
#                           'levels': 0.16666666666666666,
#                           'other': 0.16666666666666666,
#                           'times': 0.16666666666666666,
#                           'tournaments': 0.16666666666666666}),
#              ('all',
#               'levels'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 0.5,
#                           'of': 0.5}),
#              ('levels',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'society': 0.5,
#                           'womens': 0.5}),
#              ('of',
#               'society'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1.0}),
#              ('society',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'at': 1.0}),
#              ('and',
#               'at'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'all': 0.2,
#                           'least': 0.6,
#                           'the': 0.2}),
#              ('all',
#               'ages'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 1.0}),
#              ('ages',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('the',
#               'sport'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'can': 0.5,
#                           'has': 0.5}),
#              ('sport',
#               'can'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'be': 1.0}),
#              ('played',
#               'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'ablebodied': 0.3333333333333333,
#                           'anyone': 0.3333333333333333,
#                           'millions': 0.3333333333333333}),
#              ('by',
#               'anyone'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'who': 1.0}),
#              ('anyone',
#               'who'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'can': 1.0}),
#              ('who',
#               'can'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'hold': 1.0}),
#              ('can',
#               'hold'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 1.0}),
#              ('hold',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'racket': 1.0}),
#              ('racket',
#               'including'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'wheelchair': 1.0}),
#              ('including',
#               'wheelchair'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'users': 1.0}),
#              ('wheelchair',
#               'users'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 0.5,
#                           'only.in': 0.5}),
#              ('users',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('the',
#               'modern'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'game': 0.6666666666666666,
#                           'style': 0.3333333333333333}),
#              ('modern',
#               'game'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 0.5,
#                           'rackets': 0.5}),
#              ('game',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'tennis': 0.5,
#                           'the': 0.5}),
#              ('of',
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'after': 0.09090909090909091,
#                           'former': 0.09090909090909091,
#                           'is': 0.09090909090909091,
#                           'memorabilia': 0.09090909090909091,
#                           'must': 0.09090909090909091,
#                           'originated': 0.09090909090909091,
#                           'professionals': 0.09090909090909091,
#                           'stems': 0.09090909090909091,
#                           'strings': 0.18181818181818182,
#                           'the': 0.09090909090909091}),
#              ('tennis',
#               'originated'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'in': 1.0}),
#              ('originated',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'birmingham': 1.0}),
#              ('in',
#               'birmingham'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'england': 0.3333333333333333,
#                           'in': 0.6666666666666666}),
#              ('birmingham',
#               'england'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'in': 1.0}),
#              ('england',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('in',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'air': 0.017857142857142856,
#                           'atp': 0.05357142857142857,
#                           'box.experienced': 0.017857142857142856,
#                           'centre': 0.03571428571428571,
#                           'chair.in': 0.017857142857142856,
#                           'directors': 0.017857142857142856,
#                           'doubles': 0.017857142857142856,
#                           'ensuing': 0.017857142857142856,
#                           'far': 0.017857142857142856,
#                           'final': 0.017857142857142856,
#                           'first': 0.03571428571428571,
#                           'following': 0.017857142857142856,
#                           'four': 0.017857142857142856,
#                           'future': 0.017857142857142856,
#                           'game': 0.017857142857142856,
#                           'history': 0.03571428571428571,
#                           'hopes': 0.017857142857142856,
#                           'junior': 0.017857142857142856,
#                           'late': 0.017857142857142856,
#                           'latter': 0.03571428571428571,
#                           'lead': 0.03571428571428571,
#                           'major': 0.017857142857142856,
#                           'modern': 0.017857142857142856,
#                           'next': 0.017857142857142856,
#                           'olympics': 0.017857142857142856,
#                           'open': 0.03571428571428571,
#                           'region': 0.017857142857142856,
#                           'regular': 0.017857142857142856,
#                           's': 0.07142857142857142,
#                           's.': 0.05357142857142857,
#                           'servers': 0.017857142857142856,
#                           'service': 0.017857142857142856,
#                           'singles': 0.03571428571428571,
#                           'tiebreak': 0.017857142857142856,
#                           'united': 0.017857142857142856,
#                           'us': 0.03571428571428571,
#                           'vicinity': 0.017857142857142856,
#                           'world': 0.05357142857142857,
#                           'worlds': 0.017857142857142856}),
#              ('the',
#               'late'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'s': 0.5,
#                           'th': 0.5}),
#              ('late',
#               'th'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'century': 1.0}),
#              ('th',
#               'century'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 0.18181818181818182,
#                           'as': 0.18181818181818182,
#                           'by': 0.09090909090909091,
#                           'directly': 0.09090909090909091,
#                           'northern': 0.09090909090909091,
#                           'that': 0.09090909090909091,
#                           'the': 0.09090909090909091,
#                           'to': 0.09090909090909091,
#                           'until': 0.09090909090909091}),
#              ('century',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'lawn': 0.5,
#                           'shotmaking': 0.5}),
#              ('as',
#               'lawn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'tennis': 1.0}),
#              ('lawn',
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 0.1111111111111111,
#                           'and': 0.1111111111111111,
#                           'association': 0.2222222222222222,
#                           'club': 0.1111111111111111,
#                           'federation': 0.1111111111111111,
#                           'for': 0.1111111111111111,
#                           'most': 0.1111111111111111,
#                           'was': 0.1111111111111111}),
#              ('tennis',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'according': 0.125,
#                           'each': 0.125,
#                           'in': 0.125,
#                           'it': 0.125,
#                           'the': 0.125,
#                           'together': 0.125,
#                           'when': 0.125,
#                           'with': 0.125}),
#              ('.',
#               'it'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'allows': 0.13333333333333333,
#                           'can': 0.06666666666666667,
#                           'had': 0.06666666666666667,
#                           'is': 0.6,
#                           'ranked': 0.06666666666666667,
#                           'was': 0.06666666666666667}),
#              ('it',
#               'had'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'close': 1.0}),
#              ('had',
#               'close'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'connections': 1.0}),
#              ('close',
#               'connections'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'both': 1.0}),
#              ('connections',
#               'both'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 1.0}),
#              ('both',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'various': 1.0}),
#              ('to',
#               'various'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'field': 1.0}),
#              ('various',
#               'field'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'lawn': 1.0}),
#              ('field',
#               'lawn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'games': 1.0}),
#              ('lawn',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'such': 1.0}),
#              ('games',
#               'such'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'as': 1.0}),
#              ('such',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'at': 0.0625,
#                           'australian': 0.0625,
#                           'boris': 0.0625,
#                           'croquet': 0.0625,
#                           'golf': 0.0625,
#                           'jamie': 0.0625,
#                           'martina': 0.0625,
#                           'monica': 0.0625,
#                           'natural': 0.0625,
#                           'nylon': 0.0625,
#                           'rain': 0.0625,
#                           'roger': 0.0625,
#                           'synthetic': 0.0625,
#                           'titanium': 0.0625,
#                           'wheelchair': 0.0625,
#                           'wimbledon': 0.0625}),
#              ('as',
#               'croquet'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1.0}),
#              ('croquet',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'bowls': 1.0}),
#              ('and',
#               'bowls'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'as': 1.0}),
#              ('bowls',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'well': 1.0}),
#              ('as',
#               'well'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'as': 1.0}),
#              ('well',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 0.2,
#                           'being': 0.2,
#                           'people': 0.2,
#                           'to': 0.2,
#                           'world': 0.2}),
#              ('as',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('to',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'abandonment': 0.02857142857142857,
#                           'amount': 0.02857142857142857,
#                           'atp': 0.02857142857142857,
#                           'canadian': 0.02857142857142857,
#                           'champion': 0.02857142857142857,
#                           'codification': 0.02857142857142857,
#                           'coiling': 0.02857142857142857,
#                           'court': 0.05714285714285714,
#                           'following': 0.02857142857142857,
#                           'front': 0.02857142857142857,
#                           'ground': 0.02857142857142857,
#                           'inside': 0.02857142857142857,
#                           'lengthened': 0.02857142857142857,
#                           'list': 0.02857142857142857,
#                           'mark': 0.02857142857142857,
#                           'masters': 0.02857142857142857,
#                           'net': 0.08571428571428572,
#                           'number': 0.02857142857142857,
#                           'older': 0.02857142857142857,
#                           'one': 0.02857142857142857,
#                           'opponent': 0.02857142857142857,
#                           'other': 0.02857142857142857,
#                           'pace': 0.02857142857142857,
#                           'receiver': 0.08571428571428572,
#                           'same': 0.02857142857142857,
#                           'stroke': 0.05714285714285714,
#                           'tour': 0.02857142857142857,
#                           'use': 0.02857142857142857,
#                           'way': 0.02857142857142857}),
#              ('the',
#               'older'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'racket': 1.0}),
#              ('older',
#               'racket'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'sport': 1.0}),
#              ('sport',
#               'today'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'called': 1.0}),
#              ('today',
#               'called'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'real': 1.0}),
#              ('called',
#               'real'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'tennis.the': 1.0}),
#              ('real',
#               'tennis.the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'rules': 1.0}),
#              ('tennis.the',
#               'rules'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'of': 1.0}),
#              ('rules',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'modern': 0.3333333333333333,
#                           'tennis': 0.6666666666666666}),
#              ('of',
#               'modern'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'rules': 0.3333333333333333,
#                           'tennis': 0.6666666666666666}),
#              ('modern',
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 0.16666666666666666,
#                           'balls': 0.16666666666666666,
#                           'court': 0.16666666666666666,
#                           'especially': 0.16666666666666666,
#                           'have': 0.16666666666666666,
#                           'open': 0.16666666666666666}),
#              ('tennis',
#               'have'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'changed': 1.0}),
#              ('have',
#               'changed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'little': 0.5,
#                           'over': 0.5}),
#              ('changed',
#               'little'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'since': 1.0}),
#              ('little',
#               'since'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('since',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'s.': 1.0}),
#              ('the',
#               's.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 0.25,
#                           'andre': 0.25,
#                           'natural': 0.25,
#                           'two': 0.25}),
#              ('s.',
#               'two'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'exceptions': 1.0}),
#              ('two',
#               'exceptions'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'are': 1.0}),
#              ('exceptions',
#               'are'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'that': 1.0}),
#              ('are',
#               'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'until': 1.0}),
#              ('that',
#               'until'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('until',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'beginning': 0.3333333333333333,
#                           'server': 0.3333333333333333,
#                           'th': 0.3333333333333333}),
#              ('the',
#               'server'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 0.058823529411764705,
#                           'and': 0.058823529411764705,
#                           'double': 0.058823529411764705,
#                           'gets': 0.058823529411764705,
#                           'had': 0.058823529411764705,
#                           'has': 0.058823529411764705,
#                           'may': 0.058823529411764705,
#                           'misses': 0.058823529411764705,
#                           'retakes': 0.058823529411764705,
#                           'serves': 0.058823529411764705,
#                           'starts': 0.058823529411764705,
#                           'taking': 0.058823529411764705,
#                           'the': 0.058823529411764705,
#                           'then': 0.058823529411764705,
#                           'to': 0.058823529411764705,
#                           'will': 0.11764705882352941}),
#              ('server',
#               'had'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'to': 1.0}),
#              ('had',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'keep': 1.0}),
#              ('to',
#               'keep'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'one': 1.0}),
#              ('keep',
# ...
#              ('by',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'associated': 0.05263157894736842,
#                           'atp': 0.10526315789473684,
#                           'balls': 0.05263157894736842,
#                           'bleacher': 0.05263157894736842,
#                           'chair': 0.05263157894736842,
#                           'efforts': 0.05263157894736842,
#                           'first': 0.05263157894736842,
#                           'game': 0.05263157894736842,
#                           'hawkeye': 0.05263157894736842,
#                           'iltf': 0.05263157894736842,
#                           'international': 0.10526315789473684,
#                           'opponent': 0.05263157894736842,
#                           'public.there': 0.05263157894736842,
#                           'then': 0.05263157894736842,
#                           'winner': 0.10526315789473684,
#                           'winning': 0.05263157894736842}),
#              ('tennis',
#               'after'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'watching': 1.0}),
#              ('after',
#               'watching'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'british': 1.0}),
#              ('watching',
#               'british'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'army': 1.0}),
#              ('army',
#               'officers'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'play': 1.0}),
#              ('officers',
#               'play'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 1.0}),
#              ('play',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'any': 0.14285714285714285,
#                           'beginners': 0.14285714285714285,
#                           'she': 0.14285714285714285,
#                           'talented': 0.14285714285714285,
#                           'the': 0.42857142857142855}),
#              ('she',
#               'laid'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'out': 1.0}),
#              ('laid',
#               'out'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 1.0}),
#              ('out',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'tennis': 1.0}),
#              ('tennis',
#               'court'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'at': 0.5,
#                           'owes': 0.5}),
#              ('court',
#               'at'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('the',
#               'staten'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'island': 1.0}),
#              ('staten',
#               'island'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'cricket': 0.5,
#                           'new': 0.5}),
#              ('island',
#               'cricket'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'club': 1.0}),
#              ('cricket',
#               'club'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'at': 1.0}),
#              ('club',
#               'at'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'camp': 1.0}),
#              ('at',
#               'camp'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'washington': 1.0}),
#              ('camp',
#               'washington'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'tompkinsville': 1.0}),
#              ('washington',
#               'tompkinsville'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'staten': 1.0}),
#              ('tompkinsville',
#               'staten'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'island': 1.0}),
#              ('island',
#               'new'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'york': 1.0}),
#              ('new',
#               'york'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 1.0}),
#              ('york',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('first',
#               'american'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'national': 1.0}),
#              ('american',
#               'national'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'championship': 1.0}),
#              ('national',
#               'championship'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'was': 1.0}),
#              ('championship',
#               'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'created': 0.3333333333333333,
#                           'dropped': 0.3333333333333333,
#                           'played': 0.3333333333333333}),
#              ('was',
#               'played'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'there': 1.0}),
#              ('played',
#               'there'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'in': 1.0}),
#              ('there',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'september': 1.0}),
#              ('in',
#               'september'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 1.0}),
#              ('september',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'an': 1.0}),
#              ('.',
#               'an'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'englishman': 0.3333333333333333,
#                           'exception': 0.3333333333333333,
#                           'extra': 0.3333333333333333}),
#              ('an',
#               'englishman'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'named': 1.0}),
#              ('englishman',
#               'named'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'o.e': 1.0}),
#              ('named',
#               'o.e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 1.0}),
#              ('o.e',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'woodhouse': 1.0}),
#              ('.',
#               'woodhouse'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'won': 1.0}),
#              ('woodhouse',
#               'won'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('won',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'calendar': 0.5,
#                           'singles': 0.5}),
#              ('the',
#               'singles'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'career': 0.1,
#                           'competition': 0.1,
#                           'court': 0.1,
#                           'draw': 0.2,
#                           'draws': 0.1,
#                           'player': 0.1,
#                           'sidelines': 0.1,
#                           'title': 0.1,
#                           'winner': 0.1}),
#              ('singles',
#               'title'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 1.0}),
#              ('title',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 1.0}),
#              ('a',
#               'silver'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'cup': 1.0}),
#              ('silver',
#               'cup'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'worth': 1.0}),
#              ('cup',
#               'worth'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'by': 1.0}),
#              ('worth',
#               'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'defeating': 1.0}),
#              ('by',
#               'defeating'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'canadian': 1.0}),
#              ('defeating',
#               'canadian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'i.': 1.0}),
#              ('canadian',
#               'i.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'f.': 1.0}),
#              ('i.',
#               'f.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'hellmuth': 1.0}),
#              ('f.',
#               'hellmuth'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 1.0}),
#              ('hellmuth',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'there': 1.0}),
#              ('.',
#               'there'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'also': 0.1111111111111111,
#                           'are': 0.4444444444444444,
#                           'can': 0.1111111111111111,
#                           'is': 0.1111111111111111,
#                           'was': 0.1111111111111111,
#                           'were': 0.1111111111111111}),
#              ('a',
#               'doubles'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'match': 0.16666666666666666,
#                           'pairing': 0.16666666666666666,
#                           'sideline': 0.16666666666666666,
#                           'team': 0.5}),
#              ('doubles',
#               'match'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'which': 1.0}),
#              ('match',
#               'which'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'was': 1.0}),
#              ('which',
#               'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'by': 0.5,
#                           'won': 0.5}),
#              ('was',
#               'won'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'by': 1.0}),
#              ('won',
#               'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'a': 0.3333333333333333,
#                           'scoring': 0.3333333333333333,
#                           'the': 0.3333333333333333}),
#              ('a',
#               'local'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'pair': 1.0}),
#              ('local',
#               'pair'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 1.0}),
#              ('pair',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'there': 1.0}),
#              ('there',
#               'were'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'different': 1.0}),
#              ('were',
#               'different'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'rules': 1.0}),
#              ('different',
#               'rules'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'at': 1.0}),
#              ('rules',
#               'at'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'each': 1.0}),
#              ('at',
#               'each'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'club': 1.0}),
#              ('each',
#               'club'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'.': 1.0}),
#              ('club',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('in',
#               'boston'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'was': 1.0}),
#              ('boston',
#               'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'larger': 1.0}),
#              ('was',
#               'larger'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'than': 1.0}),
#              ('larger',
#               'than'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('than',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'allowed': 0.125,
#                           'forehand': 0.125,
#                           'lower': 0.125,
#                           'one': 0.125,
#                           'opponent': 0.375,
#                           'reach': 0.125}),
#              ('the',
#               'one'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'major': 0.3333333333333333,
#                           'normally': 0.3333333333333333,
#                           'published': 0.3333333333333333}),
#              ('one',
#               'normally'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'used': 1.0}),
#              ('normally',
#               'used'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'in': 1.0}),
#              ('used',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'modern': 0.5,
#                           'new': 0.5}),
#              ('in',
#               'new'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'york.on': 1.0}),
#              ('new',
#               'york.on'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'may': 1.0}),
#              ('york.on',
#               'may'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('may',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'oldest': 0.5,
#                           'tennis': 0.5}),
#              ('the',
#               'oldest'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'nationwide': 1.0}),
#              ('oldest',
#               'nationwide'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'tennis': 1.0}),
#              ('nationwide',
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'organization': 1.0}),
#              ('tennis',
#               'organization'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'in': 1.0}),
#              ('organization',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('world',
#               'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'formed': 1.0}),
#              ('was',
#               'formed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('formed',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'united': 1.0}),
#              ('the',
#               'united'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'states': 1.0}),
#              ('united',
#               'states'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'and': 0.3333333333333333,
#                           'national': 0.16666666666666666,
#                           'tennis': 0.5}),
#              ('states',
#               'national'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'lawn': 1.0}),
#              ('national',
#               'lawn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'tennis': 1.0}),
#              ('tennis',
#               'association'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'administers': 0.125,
#                           'and': 0.125,
#                           'in': 0.125,
#                           'now': 0.125,
#                           'to': 0.125,
#                           'us': 0.125,
#                           'wimbledon': 0.125,
#                           'wta': 0.125}),
#              ('association',
#               'now'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'the': 1.0}),
#              ('now',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'international': 0.3333333333333333,
#                           'united': 0.3333333333333333,
#                           'us': 0.3333333333333333}),
#              ('states',
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'association': 1.0}),
#              ('association',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>>, {'order': 1.0}),
#              ...})

# %% [markdown]
# ---
# # Provide the input

# %%
text_input = input('Enter the Text (Only 2 Words are Required) :')
text_tokenized = text_input.split(sep = ' ')
# Out:
# Enter the Text (Only 2 Words are Required) :volley is

# %%
token_length = len(text_tokenized)

# %%
values_3_gram = model_3_gram.get((text_tokenized[token_length-2], text_tokenized[token_length-1]), '<NA>')
values_3_gram
# Out:
# defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#             {'a': 0.3333333333333333,
#              'hit': 0.3333333333333333,
#              'made': 0.3333333333333333})

# %%
if(values_3_gram == '<NA>'):
    pred_ngrams = dict(model_2_gram[text_tokenized[token_length-1]])
else:
    pred_ngrams = dict(model_3_gram[text_tokenized[token_length-2],text_tokenized[token_length - 1]])

# %%
pred_ngrams
# Out:
# {'a': 0.3333333333333333,
#  'hit': 0.3333333333333333,
#  'made': 0.3333333333333333}

# %%
import random
# Generating a random number
rand_no = random.uniform(0, 1)
print('rand_no',rand_no)

import numpy as np
position = np.where(np.array(list(pred_ngrams.values())).cumsum() > rand_no)[0][0]
print('position',position)
# Out:
# rand_no 0.36483716388469767
# position 20

# %%
list(pred_ngrams.keys())[position]
# Out:
# 'referred'

# %% [markdown]
# ---
# # Suggested Next Word

# %%
print('Next Suggested Word is :', list(pred_ngrams.keys())[position])
# Out:
# Next Suggested Word is : referred
